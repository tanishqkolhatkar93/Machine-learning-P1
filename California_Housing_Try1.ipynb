# %% [markdown]
# <a href="https://colab.research.google.com/github/vaasu2002/Machine-Learning-Projects/blob/main/California_Housing_Try1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=raMXzdkueUI

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/content/housing.csv")

# %%
df
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 0        -122.23     37.88  ...            452600.0         NEAR BAY
# 1        -122.22     37.86  ...            358500.0         NEAR BAY
# 2        -122.24     37.85  ...            352100.0         NEAR BAY
# 3        -122.25     37.85  ...            341300.0         NEAR BAY
# 4        -122.25     37.85  ...            342200.0         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...             78100.0           INLAND
# 20636    -121.21     39.49  ...             77100.0           INLAND
# 20637    -121.22     39.43  ...             92300.0           INLAND
# 20638    -121.32     39.43  ...             84700.0           INLAND
# 20639    -121.24     39.37  ...             89400.0           INLAND
#
# [20640 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.corr()
# Out:
#                     longitude  latitude  ...  median_income  median_house_value
# longitude            1.000000 -0.924664  ...      -0.015176           -0.045967
# latitude            -0.924664  1.000000  ...      -0.079809           -0.144160
# housing_median_age  -0.108197  0.011173  ...      -0.119034            0.105623
# total_rooms          0.044568 -0.036100  ...       0.198050            0.134153
# total_bedrooms       0.069608 -0.066983  ...      -0.007723            0.049686
# population           0.099773 -0.108785  ...       0.004834           -0.024650
# households           0.055310 -0.071035  ...       0.013033            0.065843
# median_income       -0.015176 -0.079809  ...       1.000000            0.688075
# median_house_value  -0.045967 -0.144160  ...       0.688075            1.000000
#
# [9 rows x 9 columns]

# %%
df.corr()['median_house_value']
# Out:
# longitude            -0.045967
# latitude             -0.144160
# housing_median_age    0.105623
# total_rooms           0.134153
# total_bedrooms        0.049686
# population           -0.024650
# households            0.065843
# median_income         0.688075
# median_house_value    1.000000
# Name: median_house_value, dtype: float64

# %% [markdown]
# **median_income** has highest correlation with taget(median_house_value)

# %%
df.hist(bins=50,figsize=(21,18))
plt.show()

# %%
df['median_income'].hist(bins=50)
plt.show()

# %% [markdown]
# we are adding one more column into our dataframe called income_catogory. Basically converting continous variable to categorical variables.

# %%
df['income_catogory']= pd.cut(df['median_income'],
                         bins = [0.,1.5,3.0,4.5,6., np.inf],
                         labels = [1,2,3,4,5])
df['income_catogory'].hist()

# %% [markdown]
# we can see that there are very few people in lower income group. One row is representing one district. 1 represents poorer districts. Poorer districts are lesser in this dataset.This means this dataset is bias towards the rich districts. district 5 has most income but the data avaibale for them is also higher than low income district(1)

# %%
df
# Out:
#        longitude  latitude  ...  ocean_proximity  income_catogory
# 0        -122.23     37.88  ...         NEAR BAY                5
# 1        -122.22     37.86  ...         NEAR BAY                5
# 2        -122.24     37.85  ...         NEAR BAY                5
# 3        -122.25     37.85  ...         NEAR BAY                4
# 4        -122.25     37.85  ...         NEAR BAY                3
# ...          ...       ...  ...              ...              ...
# 20635    -121.09     39.48  ...           INLAND                2
# 20636    -121.21     39.49  ...           INLAND                2
# 20637    -121.22     39.43  ...           INLAND                2
# 20638    -121.32     39.43  ...           INLAND                2
# 20639    -121.24     39.37  ...           INLAND                2
#
# [20640 rows x 11 columns]

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42)
for train_index, test_index in split.split(df, df["income_catogory"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
df.shape
# Out:
# (20640, 11)

# %%
strat_train_set.shape
# Out:
# (15480, 11)

# %%
strat_test_set.shape
# Out:
# (5160, 11)

# %%
strat_train_set.drop("income_catogory", axis=1, inplace=True)
strat_test_set.drop("income_catogory", axis=1, inplace=True)

"""for set_ in (strat_train_set, strat_test_set):
    set_.<<your code goes here>>("income_cat", axis=1, inplace=True)"""
# Out:
# 'for set_ in (strat_train_set, strat_test_set):\n    set_.<<your code goes here>>("income_cat", axis=1, inplace=True)'

# %% [markdown]
# housing only represents 75% of dataset(training)

# %%
import matplotlib.image as mpimg
california_img=mpimg.imread('/content/california-county-map.gif')
ax = df.plot(kind="scatter", x="longitude", y="latitude", figsize=(10,7),
                       s=df['population']/100, label="Population",
                       c="median_house_value", cmap=plt.get_cmap("jet"),
                       colorbar=False, alpha=0.4,
                      )
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5,
           cmap=plt.get_cmap("jet"))
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = df["median_house_value"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar(ticks=tick_values/prices.max())
cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
cbar.set_label('Median House Value', fontsize=16)

plt.legend(fontsize=16)
plt.show()

# %%
df["rooms_per_household"] = df["total_rooms"]/df["households"]
df["bedrooms_per_room"] = df["total_bedrooms"]/df["total_rooms"]
df["population_per_household"]=df["population"]/df["households"]

# %%
df.head()
# Out:
#    longitude  latitude  ...  bedrooms_per_room  population_per_household
# 0    -122.23     37.88  ...           0.146591                  2.555556
# 1    -122.22     37.86  ...           0.155797                  2.109842
# 2    -122.24     37.85  ...           0.129516                  2.802260
# 3    -122.25     37.85  ...           0.184458                  2.547945
# 4    -122.25     37.85  ...           0.172096                  2.181467
#
# [5 rows x 14 columns]

# %%
corr_matrix = df.corr()

# %%
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.688075
# rooms_per_household         0.151948
# total_rooms                 0.134153
# housing_median_age          0.105623
# households                  0.065843
# total_bedrooms              0.049686
# population_per_household   -0.023737
# population                 -0.024650
# longitude                  -0.045967
# latitude                   -0.144160
# bedrooms_per_room          -0.255880
# Name: median_house_value, dtype: float64

# %% [markdown]
# median_house_value height correlation
#
# rooms_per_household         also good
#
# better yeild than total_rooms

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)

from pandas.plotting import scatter_matrix

attributes = ["median_house_value", "median_income", "total_rooms",
              "housing_median_age"]
scatter_matrix(df[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fac3edeba50>,
# ...
#       dtype=object)

# %%
df.describe()
# Out:
#           longitude      latitude  ...  bedrooms_per_room  population_per_household
# count  20640.000000  20640.000000  ...       20433.000000              20640.000000
# mean    -119.569704     35.631861  ...           0.213039                  3.070655
# std        2.003532      2.135952  ...           0.057983                 10.386050
# min     -124.350000     32.540000  ...           0.100000                  0.692308
# 25%     -121.800000     33.930000  ...           0.175427                  2.429741
# 50%     -118.490000     34.260000  ...           0.203162                  2.818116
# 75%     -118.010000     37.710000  ...           0.239821                  3.282261
# max     -114.310000     41.950000  ...           1.000000               1243.333333
#
# [8 rows x 12 columns]

# %%
df_train_data = strat_train_set.drop("median_house_value", axis=1)

# %%
df_train_label = strat_train_set["median_house_value"].copy()

# %%
strat_train_set.head()
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 2370     -119.57     36.70  ...             72900.0           INLAND
# 7281     -118.25     33.98  ...             97200.0        <1H OCEAN
# 2714     -115.55     32.82  ...             67500.0           INLAND
# 15339    -117.31     33.18  ...             87700.0       NEAR OCEAN
# 19776    -122.23     39.86  ...             79800.0           INLAND
#
# [5 rows x 10 columns]

# %%
df_train_data.head()
# Out:
#        longitude  latitude  ...  median_income  ocean_proximity
# 2370     -119.57     36.70  ...         2.6823           INLAND
# 7281     -118.25     33.98  ...         1.7929        <1H OCEAN
# 2714     -115.55     32.82  ...         2.5664           INLAND
# 15339    -117.31     33.18  ...         2.0147       NEAR OCEAN
# 19776    -122.23     39.86  ...         1.8375           INLAND
#
# [5 rows x 9 columns]

# %%
df_train_label.head()
# Out:
# 2370     72900.0
# 7281     97200.0
# 2714     67500.0
# 15339    87700.0
# 19776    79800.0
# Name: median_house_value, dtype: float64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy="median")

# %%
df_data = df_train_data.drop("ocean_proximity", axis=1)

# %%
imputer.fit(df_data)
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='median', verbose=0)

# %%
X = imputer.transform(df_data)
housing_training = pd.DataFrame(X, columns=df_data.columns,
                      index=df_train_data.index)

# %%
housing_training.head()
# Out:
#        longitude  latitude  ...  households  median_income
# 2370     -119.57     36.70  ...       337.0         2.6823
# 7281     -118.25     33.98  ...       337.0         1.7929
# 2714     -115.55     32.82  ...       274.0         2.5664
# 15339    -117.31     33.18  ...       399.0         2.0147
# 19776    -122.23     39.86  ...       322.0         1.8375
#
# [5 rows x 8 columns]
